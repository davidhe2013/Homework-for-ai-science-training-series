# %% [markdown]
# <a href="https://colab.research.google.com/github/davidhe2013/ai-science-training-series/blob/main/2022_10_16_David_He_Session_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys, os
import time

# This limits the amount of memory used:
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"
os.environ["TF_XLA_FLAGS"] = "--tf_xla_auto_jit=2"

import tensorflow as tf



#########################################################################
# Here's the Residual layer from the first half again:
#########################################################################
class ResidualLayer(tf.keras.Model):

    def __init__(self, n_filters):
        # tf.keras.Model.__init__(self)
        super(ResidualLayer, self).__init__()

        self.conv1 = tf.keras.layers.Conv2D(
            filters     = n_filters,
            kernel_size = (3,3),
            padding     = "same"
        )

        self.norm1 = tf.keras.layers.BatchNormalization()

        self.conv2 = tf.keras.layers.Conv2D(
            filters     = n_filters,
            kernel_size = (3,3),
            padding     = "same"
        )

        self.norm2 = tf.keras.layers.BatchNormalization()

    def call(self, inputs):

        x = inputs

        output1 = self.norm1(self.conv1(inputs))

        output1 = tf.keras.activations.relu(output1)

        output2 = self.norm2(self.conv2(output1))

        return tf.keras.activations.relu(output2 + x)

#########################################################################
# Here's layer that does a spatial downsampling:
#########################################################################
class ResidualDownsample(tf.keras.Model):

    def __init__(self, n_filters):
        # tf.keras.Model.__init__(self)
        super(ResidualDownsample, self).__init__()

        self.conv1 = tf.keras.layers.Conv2D(
            filters     = n_filters,
            kernel_size = (3,3),
            padding     = "same",
            strides     = (2,2)
        )

        self.identity = tf.keras.layers.Conv2D(
            filters     = n_filters,
            kernel_size = (1,1),
            strides     = (2,2),
            padding     = "same"
        )

        self.norm1 = tf.keras.layers.BatchNormalization()

        self.conv2 = tf.keras.layers.Conv2D(
            filters     = n_filters,
            kernel_size = (3,3),
            padding     = "same"
        )

        self.norm2 = tf.keras.layers.BatchNormalization()

    @tf.function
    def call(self, inputs):

        x = self.identity(inputs)
        output1 = self.norm1(self.conv1(inputs))
        output1 = tf.keras.activations.relu(output1)

        output2 = self.norm2(self.conv2(output1))

        return tf.keras.activations.relu(output2 + x)


#########################################################################
# Armed with that, let's build ResNet (this particular one is called ResNet34)
#########################################################################

class ResNet34(tf.keras.Model):

    def __init__(self):
        super(ResNet34, self).__init__()

        self.conv_init = tf.keras.Sequential([
            tf.keras.layers.Conv2D(
                filters     = 64,
                kernel_size = (7,7),
                strides     = (2,2),
                padding     = "same",
                use_bias    = False
            ),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.ReLU(),
            tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2), padding="same")

        ])

        self.residual_series_1 = tf.keras.Sequential([
            ResidualLayer(64),
            ResidualLayer(64),
            ResidualLayer(64),
        ])

        # Increase the number of filters:
        self.downsample_1 = ResidualDownsample(128)

        self.residual_series_2 = tf.keras.Sequential([
            ResidualLayer(128),
            ResidualLayer(128),
            ResidualLayer(128),
        ])

        # Increase the number of filters:
        self.downsample_2 = ResidualDownsample(256)

        self.residual_series_3 = tf.keras.Sequential([
            ResidualLayer(256),
            ResidualLayer(256),
            ResidualLayer(256),
            ResidualLayer(256),
            ResidualLayer(256),
        ])

        # Increase the number of filters:
        self.downsample_3 = ResidualDownsample(512)


        self.residual_series_4 = tf.keras.Sequential([
            ResidualLayer(512),
            ResidualLayer(512),
        ])

        self.final_pool = tf.keras.layers.AveragePooling2D(
            pool_size=(8,8)
        )

        self.flatten = tf.keras.layers.Flatten()
        self.classifier = tf.keras.layers.Dense(1000)

    @tf.function
    def call(self, inputs):

        x = self.conv_init(inputs)

        x = self.residual_series_1(x)


        x = self.downsample_1(x)


        x = self.residual_series_2(x)

        x = self.downsample_2(x)

        x = self.residual_series_3(x)

        x = self.downsample_3(x)


        x = self.residual_series_4(x)


        x = self.final_pool(x)

        x = self.flatten(x)

        logits = self.classifier(x)

        return logits




@tf.function
def calculate_accuracy(logits, labels):
    # We calculate top1 accuracy only here:
    selected_class = tf.argmax(logits, axis=1)

    correct = tf.cast(selected_class, tf.float32) == tf.cast(labels, tf.float32)

    return tf.reduce_mean(tf.cast(correct, tf.float32))


@tf.function
def calculate_loss(logits, labels):
    loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels, logits)
    return tf.reduce_mean(loss)

@tf.function
def training_step(network, optimizer, images, labels):
    with tf.GradientTape() as tape:
        logits = network(images)
        loss = calculate_loss(logits, labels)

    gradients = tape.gradient(loss, network.trainable_variables)

    optimizer.apply_gradients(zip(gradients, network.trainable_variables))

    accuracy = calculate_accuracy(logits, labels)

    return loss, accuracy

def train_epoch(i_epoch, step_in_epoch, train_ds, val_ds, network, optimizer, BATCH_SIZE, checkpoint):
    # Here is our training loop!

    steps_per_epoch = int(1281167 / BATCH_SIZE)
    steps_validation = int(50000 / BATCH_SIZE)

    start = time.time()
    for train_images, train_labels in train_ds.take(steps_per_epoch):
        if step_in_epoch > steps_per_epoch: break
        else: step_in_epoch.assign_add(1)

        # Peform the training step for this batch
        loss, acc = training_step(network, optimizer, train_images, train_labels)
        end = time.time()
        images_per_second = BATCH_SIZE / (end - start)
        print(f"Finished step {step_in_epoch.numpy()} of {steps_per_epoch} in epoch {i_epoch.numpy()},loss={loss:.3f}, acc={acc:.3f} ({images_per_second:.3f} img/s).")
        start = time.time()

    # Save the network after every epoch:
    checkpoint.save("resnet34/model")

    # Compute the validation accuracy:
    mean_accuracy = None
    for val_images, val_labels in val_ds.take(steps_validation):
        logits = network(val_images)
        accuracy = calculate_accuracy(logits, val_labels)
        if mean_accuracy is None:
            mean_accuracy = accuracy
        else:
            mean_accuracy += accuracy

    mean_accuracy /= steps_validation

    print(f"Validation accuracy after epoch {i_epoch.numpy()}: {mean_accuracy:.4f}.")



def prepare_data_loader(BATCH_SIZE):


    tf.config.threading.set_inter_op_parallelism_threads(8)
    tf.config.threading.set_intra_op_parallelism_threads(8)

    print("Parameters set, preparing dataloading")
    #########################################################################
    # Here's the part where we load datasets:
    import json


    # What's in this function?  Tune in next week ...
    from ilsvrc_dataset import get_datasets


    class FakeHvd:

        def size(self): return 1

        def rank(self): return 0


    with open("ilsvrc.json", 'r') as f:
        config = json.load(f)

    print(json.dumps(config, indent=4))


    config['hvd'] = FakeHvd()
    config['data']['batch_size'] = BATCH_SIZE

    train_ds, val_ds = get_datasets(config)
    print("Datasets ready, creating network.")
    #########################################################################

    return train_ds, val_ds


def main():
    #########################################################################
    # Here's some configuration:
    #########################################################################
    BATCH_SIZE = 256
    N_EPOCHS = 1

    train_ds, val_ds = prepare_data_loader(BATCH_SIZE)


    example_images, example_labels = next(iter(train_ds.take(1)))


    print("Initial Image size: ", example_images.shape)
    network = ResNet34()

    output = network(example_images)
    print("output shape:", output.shape)

    print(network.summary())




    epoch = tf.Variable(initial_value=tf.constant(0, dtype=tf.dtypes.int64), name='epoch')
    step_in_epoch = tf.Variable(
        initial_value=tf.constant(0, dtype=tf.dtypes.int64),
        name='step_in_epoch')


    # We need an optimizer.  Let's use Adam:
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

    checkpoint = tf.train.Checkpoint(
        network       = network,
        optimizer     = optimizer,
        epoch         = epoch,
        step_in_epoch = step_in_epoch)

    # Restore the model, if possible:
    latest_checkpoint = tf.train.latest_checkpoint("resnet34/")
    if latest_checkpoint:
        checkpoint.restore(latest_checkpoint)

    while epoch < N_EPOCHS:
        train_epoch(epoch, step_in_epoch, train_ds, val_ds, network, optimizer, BATCH_SIZE, checkpoint)
        epoch.assign_add(1)
        step_in_epoch.assign(0)

if __name__ == "__main__":
    main()
# Out:
# Parameters set, preparing dataloading
# --------------------------------------------------------------------------
# WARNING: There was an error initializing an OpenFabrics device.
#
#   Local host:   thetagpu06
#   Local device: mlx5_0
# --------------------------------------------------------------------------
# {
#     "data": {
#         "handler": "ilsvrc_dataset",
#         "batch_size": 128,
#         "train_filelist": "/lus/grand/projects/ALCFAITP/ilsvrc_train_filelist.txt",
#         "test_filelist": "/lus/grand/projects/ALCFAITP/ilsvrc_val_filelist.txt",
#         "shuffle_buffer": 200000,
#         "reshuffle_each_iteration": true,
#         "num_parallel_readers": 8,
#         "prefectch_buffer_size": 10,
#         "crop_image_size": [
#             256,
#             256
#         ],
#         "num_classes": 1000,
#         "num_channels": 3
#     }
# }
# num labels: 1000
# build dataset /lus/grand/projects/ALCFAITP/ilsvrc_train_filelist.txt
# input filelist contains 1281167 files, estimated batches per rank 5004
# build dataset /lus/grand/projects/ALCFAITP/ilsvrc_val_filelist.txt
# input filelist contains 50000 files, estimated batches per rank 195
# Datasets ready, creating network.
# Initial Image size:  (256, 256, 256, 3)
# output shape: (256, 1000)
# Model: "res_net34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (256, 64, 64, 64)         9664
#
#  sequential_1 (Sequential)   (256, 64, 64, 64)         223104
#
#  residual_downsample (Residu  multiple                 230784
#  alDownsample)
#
#  sequential_2 (Sequential)   (256, 32, 32, 128)        888576
#
#  residual_downsample_1 (Resi  multiple                 920320
#  dualDownsample)
#
#  sequential_3 (Sequential)   (256, 16, 16, 256)        5911040
#
#  residual_downsample_2 (Resi  multiple                 3675648
#  dualDownsample)
#
#  sequential_4 (Sequential)   (256, 8, 8, 512)          9447424
#
#  average_pooling2d (AverageP  multiple                 0
#  ooling2D)
#
#  flatten (Flatten)           multiple                  0
#
#  dense (Dense)               multiple                  513000
#
# =================================================================
# Total params: 21,819,560
# Trainable params: 21,804,328
# Non-trainable params: 15,232
# _________________________________________________________________
# None
# Finished step 1 of 5004 in epoch 0,loss=140.186, acc=0.000 (16.133 img/s).
# Finished step 2 of 5004 in epoch 0,loss=97.887, acc=0.000 (977.327 img/s).
# Finished step 3 of 5004 in epoch 0,loss=58.712, acc=0.000 (621.616 img/s).
# Finished step 4 of 5004 in epoch 0,loss=41.883, acc=0.008 (582.465 img/s).
# Finished step 5 of 5004 in epoch 0,loss=28.705, acc=0.000 (550.352 img/s).
# Finished step 6 of 5004 in epoch 0,loss=18.814, acc=0.000 (566.639 img/s).
# Finished step 7 of 5004 in epoch 0,loss=14.549, acc=0.000 (548.624 img/s).
# Finished step 8 of 5004 in epoch 0,loss=11.954, acc=0.004 (530.472 img/s).
# Finished step 9 of 5004 in epoch 0,loss=9.371, acc=0.004 (588.398 img/s).
# Finished step 10 of 5004 in epoch 0,loss=8.410, acc=0.020 (552.920 img/s).
# Finished step 11 of 5004 in epoch 0,loss=7.667, acc=0.004 (572.448 img/s).
# Finished step 12 of 5004 in epoch 0,loss=7.268, acc=0.000 (614.587 img/s).
# Finished step 13 of 5004 in epoch 0,loss=6.956, acc=0.012 (579.526 img/s).
# Finished step 14 of 5004 in epoch 0,loss=6.779, acc=0.004 (566.724 img/s).
# Finished step 15 of 5004 in epoch 0,loss=6.628, acc=0.012 (618.334 img/s).
# Finished step 16 of 5004 in epoch 0,loss=6.630, acc=0.004 (610.070 img/s).
# Finished step 17 of 5004 in epoch 0,loss=6.655, acc=0.004 (546.505 img/s).
# Finished step 18 of 5004 in epoch 0,loss=6.471, acc=0.008 (560.685 img/s).
# Finished step 19 of 5004 in epoch 0,loss=6.331, acc=0.020 (574.477 img/s).
# Finished step 20 of 5004 in epoch 0,loss=6.446, acc=0.008 (607.972 img/s).
# Finished step 21 of 5004 in epoch 0,loss=6.430, acc=0.004 (552.622 img/s).
# Finished step 22 of 5004 in epoch 0,loss=6.378, acc=0.016 (562.673 img/s).
# Finished step 23 of 5004 in epoch 0,loss=6.308, acc=0.000 (551.408 img/s).
# Finished step 24 of 5004 in epoch 0,loss=6.216, acc=0.012 (554.508 img/s).
# Finished step 25 of 5004 in epoch 0,loss=6.183, acc=0.004 (513.765 img/s).
# Finished step 26 of 5004 in epoch 0,loss=6.153, acc=0.016 (547.678 img/s).
# Finished step 27 of 5004 in epoch 0,loss=6.223, acc=0.000 (571.550 img/s).
# Finished step 28 of 5004 in epoch 0,loss=6.048, acc=0.000 (312.582 img/s).
# Finished step 29 of 5004 in epoch 0,loss=5.969, acc=0.012 (537.272 img/s).
# Finished step 30 of 5004 in epoch 0,loss=6.152, acc=0.004 (589.278 img/s).
# Finished step 31 of 5004 in epoch 0,loss=5.995, acc=0.000 (597.337 img/s).
# Finished step 32 of 5004 in epoch 0,loss=5.878, acc=0.012 (580.847 img/s).
# Finished step 33 of 5004 in epoch 0,loss=5.855, acc=0.016 (615.307 img/s).
# Finished step 34 of 5004 in epoch 0,loss=5.819, acc=0.012 (533.165 img/s).
# Finished step 35 of 5004 in epoch 0,loss=5.871, acc=0.004 (559.423 img/s).
# Finished step 36 of 5004 in epoch 0,loss=5.801, acc=0.004 (594.512 img/s).
# Finished step 37 of 5004 in epoch 0,loss=5.793, acc=0.008 (601.245 img/s).
# Finished step 38 of 5004 in epoch 0,loss=5.715, acc=0.004 (541.421 img/s).
# Finished step 39 of 5004 in epoch 0,loss=5.753, acc=0.000 (603.784 img/s).
# Finished step 40 of 5004 in epoch 0,loss=5.694, acc=0.004 (634.730 img/s).
# Finished step 41 of 5004 in epoch 0,loss=5.668, acc=0.016 (667.732 img/s).
# Finished step 42 of 5004 in epoch 0,loss=5.696, acc=0.004 (586.846 img/s).
# Finished step 43 of 5004 in epoch 0,loss=5.529, acc=0.004 (632.964 img/s).
# Finished step 44 of 5004 in epoch 0,loss=5.547, acc=0.012 (584.373 img/s).
# Finished step 45 of 5004 in epoch 0,loss=5.632, acc=0.008 (641.324 img/s).
# Finished step 46 of 5004 in epoch 0,loss=5.511, acc=0.008 (630.116 img/s).
# Finished step 47 of 5004 in epoch 0,loss=5.488, acc=0.016 (439.286 img/s).
# Finished step 48 of 5004 in epoch 0,loss=5.470, acc=0.000 (578.293 img/s).
# Finished step 49 of 5004 in epoch 0,loss=5.465, acc=0.004 (583.681 img/s).
# Finished step 50 of 5004 in epoch 0,loss=5.385, acc=0.004 (592.565 img/s).
# Finished step 51 of 5004 in epoch 0,loss=5.534, acc=0.004 (651.857 img/s).
# Finished step 52 of 5004 in epoch 0,loss=5.368, acc=0.012 (569.427 img/s).
# Finished step 53 of 5004 in epoch 0,loss=5.443, acc=0.020 (580.572 img/s).
# Finished step 54 of 5004 in epoch 0,loss=5.414, acc=0.000 (598.241 img/s).
# Finished step 55 of 5004 in epoch 0,loss=5.386, acc=0.008 (622.557 img/s).
# Finished step 56 of 5004 in epoch 0,loss=5.465, acc=0.012 (650.880 img/s).
# Finished step 57 of 5004 in epoch 0,loss=5.373, acc=0.000 (602.313 img/s).
# Finished step 58 of 5004 in epoch 0,loss=5.296, acc=0.000 (616.984 img/s).
# Finished step 59 of 5004 in epoch 0,loss=5.386, acc=0.012 (649.621 img/s).
# Finished step 60 of 5004 in epoch 0,loss=5.409, acc=0.008 (572.963 img/s).
# Finished step 61 of 5004 in epoch 0,loss=5.372, acc=0.012 (568.773 img/s).
# Finished step 62 of 5004 in epoch 0,loss=5.346, acc=0.008 (564.151 img/s).
# Finished step 63 of 5004 in epoch 0,loss=5.279, acc=0.004 (578.802 img/s).
# Finished step 64 of 5004 in epoch 0,loss=5.271, acc=0.008 (647.635 img/s).
# Finished step 65 of 5004 in epoch 0,loss=5.336, acc=0.004 (600.725 img/s).
# Finished step 66 of 5004 in epoch 0,loss=5.416, acc=0.008 (530.472 img/s).
# Finished step 67 of 5004 in epoch 0,loss=5.227, acc=0.008 (597.892 img/s).
# Finished step 68 of 5004 in epoch 0,loss=5.285, acc=0.012 (542.299 img/s).
# Finished step 69 of 5004 in epoch 0,loss=5.262, acc=0.000 (645.362 img/s).
# Finished step 70 of 5004 in epoch 0,loss=5.391, acc=0.020 (592.791 img/s).
# Finished step 71 of 5004 in epoch 0,loss=5.295, acc=0.016 (580.217 img/s).
# Finished step 72 of 5004 in epoch 0,loss=5.260, acc=0.012 (609.010 img/s).
# Finished step 73 of 5004 in epoch 0,loss=5.216, acc=0.000 (535.288 img/s).
# Finished step 74 of 5004 in epoch 0,loss=5.261, acc=0.008 (593.663 img/s).
# Finished step 75 of 5004 in epoch 0,loss=5.357, acc=0.008 (505.264 img/s).
# Finished step 76 of 5004 in epoch 0,loss=5.359, acc=0.008 (668.588 img/s).
# Finished step 77 of 5004 in epoch 0,loss=5.185, acc=0.031 (636.154 img/s).
# Finished step 78 of 5004 in epoch 0,loss=5.156, acc=0.027 (644.208 img/s).
# Finished step 79 of 5004 in epoch 0,loss=5.248, acc=0.004 (542.961 img/s).
# Finished step 80 of 5004 in epoch 0,loss=5.337, acc=0.004 (566.801 img/s).
# Finished step 81 of 5004 in epoch 0,loss=5.200, acc=0.020 (630.742 img/s).
# Finished step 82 of 5004 in epoch 0,loss=5.307, acc=0.008 (600.537 img/s).
# Finished step 83 of 5004 in epoch 0,loss=5.334, acc=0.000 (601.408 img/s).
# Finished step 84 of 5004 in epoch 0,loss=5.212, acc=0.039 (567.982 img/s).
# Finished step 85 of 5004 in epoch 0,loss=5.305, acc=0.008 (641.830 img/s).
# Finished step 86 of 5004 in epoch 0,loss=5.290, acc=0.027 (604.845 img/s).
# Finished step 87 of 5004 in epoch 0,loss=5.279, acc=0.016 (590.668 img/s).
# Finished step 88 of 5004 in epoch 0,loss=5.371, acc=0.008 (579.673 img/s).
# Finished step 89 of 5004 in epoch 0,loss=5.278, acc=0.012 (589.055 img/s).
# Finished step 90 of 5004 in epoch 0,loss=5.315, acc=0.020 (566.152 img/s).
# Finished step 91 of 5004 in epoch 0,loss=5.224, acc=0.000 (521.177 img/s).
# Finished step 92 of 5004 in epoch 0,loss=5.199, acc=0.012 (605.210 img/s).
# Finished step 93 of 5004 in epoch 0,loss=5.166, acc=0.020 (571.344 img/s).
# Finished step 94 of 5004 in epoch 0,loss=5.210, acc=0.023 (608.181 img/s).
# Finished step 95 of 5004 in epoch 0,loss=5.349, acc=0.016 (602.188 img/s).
# Finished step 96 of 5004 in epoch 0,loss=5.236, acc=0.047 (606.281 img/s).
# Finished step 97 of 5004 in epoch 0,loss=5.247, acc=0.012 (635.175 img/s).
# Finished step 98 of 5004 in epoch 0,loss=5.285, acc=0.016 (668.936 img/s).
# Finished step 99 of 5004 in epoch 0,loss=5.163, acc=0.016 (627.248 img/s).
# Finished step 100 of 5004 in epoch 0,loss=5.203, acc=0.012 (609.848 img/s).
# Finished step 101 of 5004 in epoch 0,loss=5.173, acc=0.027 (583.397 img/s).
# Finished step 102 of 5004 in epoch 0,loss=5.208, acc=0.016 (627.651 img/s).
# Finished step 103 of 5004 in epoch 0,loss=5.203, acc=0.012 (567.543 img/s).
# Finished step 104 of 5004 in epoch 0,loss=5.143, acc=0.027 (589.987 img/s).
# Finished step 105 of 5004 in epoch 0,loss=5.167, acc=0.031 (592.916 img/s).
# Finished step 106 of 5004 in epoch 0,loss=5.292, acc=0.027 (621.490 img/s).
# Finished step 107 of 5004 in epoch 0,loss=5.238, acc=0.020 (597.692 img/s).
# Finished step 108 of 5004 in epoch 0,loss=5.124, acc=0.023 (597.129 img/s).
# Finished step 109 of 5004 in epoch 0,loss=5.228, acc=0.020 (640.005 img/s).
# Finished step 110 of 5004 in epoch 0,loss=5.297, acc=0.000 (581.760 img/s).
# Finished step 111 of 5004 in epoch 0,loss=5.128, acc=0.027 (596.509 img/s).
# Finished step 112 of 5004 in epoch 0,loss=5.135, acc=0.039 (584.222 img/s).
# Finished step 113 of 5004 in epoch 0,loss=5.215, acc=0.043 (571.850 img/s).
# Finished step 114 of 5004 in epoch 0,loss=5.142, acc=0.016 (612.270 img/s).
# Finished step 115 of 5004 in epoch 0,loss=5.066, acc=0.020 (520.895 img/s).
# Finished step 116 of 5004 in epoch 0,loss=5.279, acc=0.016 (657.026 img/s).
# Finished step 117 of 5004 in epoch 0,loss=5.178, acc=0.020 (567.485 img/s).
# Finished step 118 of 5004 in epoch 0,loss=5.157, acc=0.016 (539.961 img/s).
# Finished step 119 of 5004 in epoch 0,loss=5.219, acc=0.039 (623.220 img/s).
# Finished step 120 of 5004 in epoch 0,loss=5.211, acc=0.004 (655.980 img/s).
# Finished step 121 of 5004 in epoch 0,loss=5.183, acc=0.016 (564.407 img/s).
# Finished step 122 of 5004 in epoch 0,loss=5.076, acc=0.023 (533.693 img/s).
# Finished step 123 of 5004 in epoch 0,loss=5.122, acc=0.027 (631.625 img/s).
# Finished step 124 of 5004 in epoch 0,loss=5.195, acc=0.016 (588.492 img/s).
# Finished step 125 of 5004 in epoch 0,loss=5.103, acc=0.027 (659.604 img/s).
# Finished step 126 of 5004 in epoch 0,loss=5.093, acc=0.020 (638.384 img/s).
# Finished step 127 of 5004 in epoch 0,loss=5.176, acc=0.031 (622.595 img/s).
# Finished step 128 of 5004 in epoch 0,loss=5.099, acc=0.031 (536.840 img/s).
# Finished step 129 of 5004 in epoch 0,loss=5.190, acc=0.027 (566.787 img/s).
# Finished step 130 of 5004 in epoch 0,loss=5.236, acc=0.016 (616.689 img/s).
# Finished step 131 of 5004 in epoch 0,loss=5.125, acc=0.027 (621.345 img/s).
# Finished step 132 of 5004 in epoch 0,loss=5.248, acc=0.012 (617.459 img/s).
# Finished step 133 of 5004 in epoch 0,loss=5.281, acc=0.012 (634.627 img/s).
# Finished step 134 of 5004 in epoch 0,loss=5.114, acc=0.023 (569.236 img/s).
# Finished step 135 of 5004 in epoch 0,loss=5.206, acc=0.016 (577.827 img/s).
# Finished step 136 of 5004 in epoch 0,loss=5.053, acc=0.020 (600.558 img/s).
# Finished step 137 of 5004 in epoch 0,loss=5.036, acc=0.043 (656.317 img/s).
# Finished step 138 of 5004 in epoch 0,loss=5.084, acc=0.031 (547.127 img/s).
# Finished step 139 of 5004 in epoch 0,loss=5.110, acc=0.016 (640.165 img/s).
# Finished step 140 of 5004 in epoch 0,loss=5.172, acc=0.027 (659.552 img/s).
# Finished step 141 of 5004 in epoch 0,loss=5.220, acc=0.020 (605.935 img/s).
# Finished step 142 of 5004 in epoch 0,loss=5.172, acc=0.016 (646.891 img/s).
# Finished step 143 of 5004 in epoch 0,loss=5.292, acc=0.016 (570.941 img/s).
# Finished step 144 of 5004 in epoch 0,loss=5.170, acc=0.016 (611.652 img/s).
# Finished step 145 of 5004 in epoch 0,loss=5.103, acc=0.020 (514.206 img/s).
# Finished step 146 of 5004 in epoch 0,loss=5.193, acc=0.020 (606.404 img/s).
# Finished step 147 of 5004 in epoch 0,loss=5.191, acc=0.016 (628.782 img/s).
# Finished step 148 of 5004 in epoch 0,loss=5.105, acc=0.020 (631.072 img/s).
# Finished step 149 of 5004 in epoch 0,loss=5.138, acc=0.023 (548.677 img/s).
# Finished step 150 of 5004 in epoch 0,loss=5.151, acc=0.008 (590.985 img/s).
# Finished step 151 of 5004 in epoch 0,loss=5.084, acc=0.043 (597.088 img/s).
# Finished step 152 of 5004 in epoch 0,loss=5.136, acc=0.020 (616.462 img/s).
# Finished step 153 of 5004 in epoch 0,loss=5.134, acc=0.031 (599.829 img/s).
# Finished step 154 of 5004 in epoch 0,loss=5.168, acc=0.023 (527.968 img/s).
# Finished step 155 of 5004 in epoch 0,loss=5.129, acc=0.027 (604.058 img/s).
# Finished step 156 of 5004 in epoch 0,loss=5.118, acc=0.031 (595.997 img/s).
# Finished step 157 of 5004 in epoch 0,loss=5.119, acc=0.012 (623.527 img/s).
# Finished step 158 of 5004 in epoch 0,loss=5.043, acc=0.035 (603.334 img/s).
# Finished step 159 of 5004 in epoch 0,loss=5.051, acc=0.027 (596.667 img/s).
# Finished step 160 of 5004 in epoch 0,loss=5.034, acc=0.035 (630.457 img/s).
# Finished step 161 of 5004 in epoch 0,loss=5.123, acc=0.012 (610.791 img/s).
# Finished step 162 of 5004 in epoch 0,loss=5.178, acc=0.027 (648.385 img/s).
# Finished step 163 of 5004 in epoch 0,loss=4.965, acc=0.027 (644.881 img/s).
# Finished step 164 of 5004 in epoch 0,loss=5.263, acc=0.027 (640.377 img/s).
# Finished step 165 of 5004 in epoch 0,loss=5.142, acc=0.027 (650.344 img/s).
# Finished step 166 of 5004 in epoch 0,loss=5.223, acc=0.059 (599.945 img/s).
# Finished step 167 of 5004 in epoch 0,loss=5.110, acc=0.047 (568.086 img/s).
# Finished step 168 of 5004 in epoch 0,loss=5.050, acc=0.059 (617.910 img/s).
# Finished step 169 of 5004 in epoch 0,loss=5.330, acc=0.039 (613.456 img/s).
# Finished step 170 of 5004 in epoch 0,loss=4.977, acc=0.031 (590.209 img/s).
# Finished step 171 of 5004 in epoch 0,loss=5.177, acc=0.047 (569.558 img/s).
# Finished step 172 of 5004 in epoch 0,loss=4.915, acc=0.035 (625.773 img/s).
# Finished step 173 of 5004 in epoch 0,loss=4.942, acc=0.039 (644.241 img/s).
# Finished step 174 of 5004 in epoch 0,loss=5.170, acc=0.027 (642.243 img/s).
# Finished step 175 of 5004 in epoch 0,loss=5.208, acc=0.023 (483.319 img/s).
# Finished step 176 of 5004 in epoch 0,loss=5.125, acc=0.035 (630.274 img/s).
# Finished step 177 of 5004 in epoch 0,loss=5.041, acc=0.016 (611.160 img/s).
# Finished step 178 of 5004 in epoch 0,loss=5.199, acc=0.039 (629.233 img/s).
# Finished step 179 of 5004 in epoch 0,loss=5.205, acc=0.016 (641.441 img/s).
# Finished step 180 of 5004 in epoch 0,loss=5.124, acc=0.035 (651.506 img/s).
# Finished step 181 of 5004 in epoch 0,loss=5.168, acc=0.035 (592.127 img/s).
# Finished step 182 of 5004 in epoch 0,loss=5.101, acc=0.012 (569.661 img/s).
# Finished step 183 of 5004 in epoch 0,loss=5.188, acc=0.035 (587.184 img/s).
# Finished step 184 of 5004 in epoch 0,loss=5.103, acc=0.016 (660.745 img/s).
# Finished step 185 of 5004 in epoch 0,loss=5.050, acc=0.031 (610.481 img/s).
# Finished step 186 of 5004 in epoch 0,loss=5.025, acc=0.031 (675.210 img/s).
# Finished step 187 of 5004 in epoch 0,loss=5.073, acc=0.031 (531.323 img/s).
# Finished step 188 of 5004 in epoch 0,loss=5.038, acc=0.027 (643.455 img/s).
# Finished step 189 of 5004 in epoch 0,loss=5.074, acc=0.020 (535.178 img/s).
# Finished step 190 of 5004 in epoch 0,loss=5.135, acc=0.035 (691.880 img/s).
# Finished step 191 of 5004 in epoch 0,loss=5.162, acc=0.027 (587.485 img/s).
# Finished step 192 of 5004 in epoch 0,loss=5.155, acc=0.023 (609.159 img/s).
# Finished step 193 of 5004 in epoch 0,loss=5.053, acc=0.016 (532.721 img/s).
# Finished step 194 of 5004 in epoch 0,loss=5.124, acc=0.012 (643.429 img/s).
# Finished step 195 of 5004 in epoch 0,loss=5.176, acc=0.039 (603.775 img/s).
# Finished step 196 of 5004 in epoch 0,loss=5.116, acc=0.031 (633.997 img/s).
# Finished step 197 of 5004 in epoch 0,loss=5.143, acc=0.039 (585.853 img/s).
# Finished step 198 of 5004 in epoch 0,loss=5.053, acc=0.039 (568.343 img/s).
# Finished step 199 of 5004 in epoch 0,loss=5.162, acc=0.051 (587.216 img/s).
# Finished step 200 of 5004 in epoch 0,loss=5.139, acc=0.020 (577.700 img/s).
# Finished step 201 of 5004 in epoch 0,loss=5.191, acc=0.016 (598.229 img/s).
# Finished step 202 of 5004 in epoch 0,loss=5.112, acc=0.020 (670.898 img/s).
# Finished step 203 of 5004 in epoch 0,loss=5.098, acc=0.031 (590.559 img/s).
# Finished step 204 of 5004 in epoch 0,loss=5.095, acc=0.023 (600.176 img/s).
# Finished step 205 of 5004 in epoch 0,loss=5.008, acc=0.039 (631.549 img/s).
# Finished step 206 of 5004 in epoch 0,loss=4.953, acc=0.066 (632.882 img/s).
# Finished step 207 of 5004 in epoch 0,loss=5.157, acc=0.020 (577.156 img/s).
# Finished step 208 of 5004 in epoch 0,loss=5.088, acc=0.020 (574.593 img/s).
# Finished step 209 of 5004 in epoch 0,loss=5.004, acc=0.031 (564.639 img/s).
# Finished step 210 of 5004 in epoch 0,loss=5.044, acc=0.043 (579.403 img/s).
# Finished step 211 of 5004 in epoch 0,loss=5.139, acc=0.043 (611.588 img/s).
# Finished step 212 of 5004 in epoch 0,loss=5.032, acc=0.031 (639.626 img/s).
# Finished step 213 of 5004 in epoch 0,loss=5.233, acc=0.035 (679.574 img/s).
# Finished step 214 of 5004 in epoch 0,loss=4.997, acc=0.035 (470.614 img/s).
# Finished step 215 of 5004 in epoch 0,loss=5.037, acc=0.039 (611.407 img/s).
# Finished step 216 of 5004 in epoch 0,loss=5.051, acc=0.020 (649.065 img/s).
# Finished step 217 of 5004 in epoch 0,loss=5.133, acc=0.020 (617.224 img/s).
# Finished step 218 of 5004 in epoch 0,loss=5.168, acc=0.031 (595.364 img/s).
# Finished step 219 of 5004 in epoch 0,loss=5.043, acc=0.031 (639.157 img/s).
# Finished step 220 of 5004 in epoch 0,loss=5.043, acc=0.043 (603.432 img/s).
# Finished step 221 of 5004 in epoch 0,loss=5.028, acc=0.051 (604.126 img/s).
# Finished step 222 of 5004 in epoch 0,loss=5.114, acc=0.051 (651.806 img/s).
# Finished step 223 of 5004 in epoch 0,loss=4.986, acc=0.035 (540.635 img/s).
# Finished step 224 of 5004 in epoch 0,loss=5.022, acc=0.043 (678.046 img/s).
# Finished step 225 of 5004 in epoch 0,loss=5.007, acc=0.016 (635.565 img/s).
# Finished step 226 of 5004 in epoch 0,loss=5.140, acc=0.031 (645.224 img/s).
# Finished step 227 of 5004 in epoch 0,loss=5.006, acc=0.047 (668.871 img/s).
# Finished step 228 of 5004 in epoch 0,loss=5.172, acc=0.039 (630.421 img/s).
# Finished step 229 of 5004 in epoch 0,loss=5.032, acc=0.043 (598.599 img/s).
# Finished step 230 of 5004 in epoch 0,loss=5.043, acc=0.027 (665.762 img/s).
# Finished step 231 of 5004 in epoch 0,loss=5.039, acc=0.047 (631.727 img/s).
# Finished step 232 of 5004 in epoch 0,loss=5.197, acc=0.059 (644.854 img/s).
# Finished step 233 of 5004 in epoch 0,loss=5.057, acc=0.023 (560.554 img/s).
# Finished step 234 of 5004 in epoch 0,loss=5.033, acc=0.047 (616.574 img/s).
# Finished step 235 of 5004 in epoch 0,loss=5.138, acc=0.043 (560.094 img/s).
# Finished step 236 of 5004 in epoch 0,loss=4.848, acc=0.047 (590.878 img/s).
# Finished step 237 of 5004 in epoch 0,loss=5.024, acc=0.043 (669.396 img/s).
# Finished step 238 of 5004 in epoch 0,loss=5.018, acc=0.020 (597.325 img/s).
# Finished step 239 of 5004 in epoch 0,loss=5.164, acc=0.043 (623.164 img/s).
# Finished step 240 of 5004 in epoch 0,loss=4.998, acc=0.043 (504.659 img/s).
# Finished step 241 of 5004 in epoch 0,loss=4.907, acc=0.043 (662.171 img/s).
# Finished step 242 of 5004 in epoch 0,loss=5.129, acc=0.051 (602.185 img/s).
# Finished step 243 of 5004 in epoch 0,loss=5.120, acc=0.020 (607.687 img/s).
# Finished step 244 of 5004 in epoch 0,loss=4.945, acc=0.027 (503.311 img/s).
# Finished step 245 of 5004 in epoch 0,loss=4.998, acc=0.016 (645.710 img/s).
# Finished step 246 of 5004 in epoch 0,loss=4.912, acc=0.043 (653.080 img/s).
# Finished step 247 of 5004 in epoch 0,loss=4.989, acc=0.043 (624.024 img/s).
# Finished step 248 of 5004 in epoch 0,loss=4.973, acc=0.047 (664.368 img/s).
# Finished step 249 of 5004 in epoch 0,loss=4.929, acc=0.051 (540.265 img/s).
# Finished step 250 of 5004 in epoch 0,loss=4.926, acc=0.047 (610.548 img/s).
# Finished step 251 of 5004 in epoch 0,loss=5.065, acc=0.035 (677.006 img/s).
# Finished step 252 of 5004 in epoch 0,loss=5.005, acc=0.043 (541.233 img/s).
# Finished step 253 of 5004 in epoch 0,loss=5.052, acc=0.023 (682.664 img/s).
# Finished step 254 of 5004 in epoch 0,loss=4.927, acc=0.027 (632.171 img/s).
# Finished step 255 of 5004 in epoch 0,loss=5.142, acc=0.027 (633.370 img/s).
# Finished step 256 of 5004 in epoch 0,loss=4.905, acc=0.055 (550.056 img/s).
# Finished step 257 of 5004 in epoch 0,loss=5.096, acc=0.035 (626.400 img/s).
# Finished step 258 of 5004 in epoch 0,loss=4.980, acc=0.059 (628.888 img/s).
# Finished step 259 of 5004 in epoch 0,loss=5.111, acc=0.031 (584.654 img/s).
# Finished step 260 of 5004 in epoch 0,loss=5.018, acc=0.031 (620.769 img/s).
# Finished step 261 of 5004 in epoch 0,loss=5.100, acc=0.043 (554.653 img/s).
# Finished step 262 of 5004 in epoch 0,loss=5.032, acc=0.020 (600.989 img/s).
# Finished step 263 of 5004 in epoch 0,loss=5.196, acc=0.016 (602.593 img/s).
# Finished step 264 of 5004 in epoch 0,loss=5.024, acc=0.055 (645.129 img/s).
# Finished step 265 of 5004 in epoch 0,loss=4.966, acc=0.027 (674.793 img/s).
# Finished step 266 of 5004 in epoch 0,loss=5.149, acc=0.043 (665.202 img/s).
# Finished step 267 of 5004 in epoch 0,loss=4.855, acc=0.043 (615.889 img/s).
# Finished step 268 of 5004 in epoch 0,loss=5.046, acc=0.035 (559.532 img/s).
# Finished step 269 of 5004 in epoch 0,loss=5.073, acc=0.047 (634.496 img/s).
# Finished step 270 of 5004 in epoch 0,loss=5.048, acc=0.062 (579.383 img/s).
# Finished step 271 of 5004 in epoch 0,loss=4.971, acc=0.059 (638.675 img/s).
# Finished step 272 of 5004 in epoch 0,loss=5.060, acc=0.035 (631.281 img/s).
# Finished step 273 of 5004 in epoch 0,loss=4.933, acc=0.035 (637.469 img/s).
# Finished step 274 of 5004 in epoch 0,loss=5.005, acc=0.031 (633.134 img/s).
# Finished step 275 of 5004 in epoch 0,loss=4.938, acc=0.055 (577.538 img/s).
# Finished step 276 of 5004 in epoch 0,loss=5.007, acc=0.039 (643.099 img/s).
# Finished step 277 of 5004 in epoch 0,loss=4.948, acc=0.047 (626.156 img/s).
# Finished step 278 of 5004 in epoch 0,loss=5.006, acc=0.035 (575.062 img/s).
# Finished step 279 of 5004 in epoch 0,loss=5.027, acc=0.043 (577.101 img/s).
# Finished step 280 of 5004 in epoch 0,loss=5.001, acc=0.062 (578.682 img/s).
# Finished step 281 of 5004 in epoch 0,loss=5.139, acc=0.047 (660.605 img/s).
# Finished step 282 of 5004 in epoch 0,loss=5.018, acc=0.027 (639.665 img/s).
# Finished step 283 of 5004 in epoch 0,loss=5.019, acc=0.039 (608.767 img/s).
# Finished step 284 of 5004 in epoch 0,loss=4.895, acc=0.035 (625.876 img/s).
# Finished step 285 of 5004 in epoch 0,loss=5.081, acc=0.031 (682.688 img/s).
# Finished step 286 of 5004 in epoch 0,loss=5.002, acc=0.027 (654.882 img/s).
# Finished step 287 of 5004 in epoch 0,loss=5.210, acc=0.043 (587.159 img/s).
# Finished step 288 of 5004 in epoch 0,loss=5.023, acc=0.023 (650.553 img/s).
# Finished step 289 of 5004 in epoch 0,loss=5.125, acc=0.023 (607.301 img/s).
# Finished step 290 of 5004 in epoch 0,loss=4.984, acc=0.039 (622.249 img/s).
# Finished step 291 of 5004 in epoch 0,loss=5.123, acc=0.027 (623.689 img/s).
# Finished step 292 of 5004 in epoch 0,loss=5.098, acc=0.031 (670.140 img/s).
# Finished step 293 of 5004 in epoch 0,loss=5.092, acc=0.031 (602.992 img/s).
# Finished step 294 of 5004 in epoch 0,loss=5.082, acc=0.020 (651.813 img/s).
# Finished step 295 of 5004 in epoch 0,loss=4.928, acc=0.043 (589.576 img/s).
# Finished step 296 of 5004 in epoch 0,loss=5.096, acc=0.047 (674.773 img/s).
# Finished step 297 of 5004 in epoch 0,loss=5.004, acc=0.039 (647.386 img/s).
# Finished step 298 of 5004 in epoch 0,loss=5.013, acc=0.090 (633.850 img/s).
# Finished step 299 of 5004 in epoch 0,loss=4.940, acc=0.059 (690.964 img/s).
# Finished step 300 of 5004 in epoch 0,loss=4.963, acc=0.051 (643.242 img/s).
# Finished step 301 of 5004 in epoch 0,loss=5.041, acc=0.043 (596.421 img/s).
# Finished step 302 of 5004 in epoch 0,loss=5.069, acc=0.031 (607.588 img/s).
# Finished step 303 of 5004 in epoch 0,loss=5.064, acc=0.039 (703.802 img/s).
# Finished step 304 of 5004 in epoch 0,loss=5.137, acc=0.074 (708.536 img/s).
# Finished step 305 of 5004 in epoch 0,loss=5.103, acc=0.012 (207.050 img/s).
# Finished step 306 of 5004 in epoch 0,loss=5.045, acc=0.035 (275.096 img/s).
# Finished step 307 of 5004 in epoch 0,loss=4.955, acc=0.043 (226.358 img/s).
# Finished step 308 of 5004 in epoch 0,loss=4.934, acc=0.070 (348.789 img/s).
# Finished step 309 of 5004 in epoch 0,loss=5.060, acc=0.055 (311.115 img/s).
# Finished step 310 of 5004 in epoch 0,loss=4.835, acc=0.066 (269.889 img/s).
# Finished step 311 of 5004 in epoch 0,loss=4.952, acc=0.051 (230.136 img/s).
# Finished step 312 of 5004 in epoch 0,loss=4.874, acc=0.047 (340.856 img/s).
# Finished step 313 of 5004 in epoch 0,loss=4.979, acc=0.023 (574.132 img/s).
# Finished step 314 of 5004 in epoch 0,loss=4.957, acc=0.059 (602.359 img/s).
# Finished step 315 of 5004 in epoch 0,loss=5.221, acc=0.062 (579.259 img/s).
# Finished step 316 of 5004 in epoch 0,loss=4.976, acc=0.047 (560.065 img/s).
# Finished step 317 of 5004 in epoch 0,loss=5.103, acc=0.039 (654.396 img/s).
# Finished step 318 of 5004 in epoch 0,loss=5.041, acc=0.023 (582.702 img/s).
# Finished step 319 of 5004 in epoch 0,loss=5.029, acc=0.035 (647.921 img/s).
# Finished step 320 of 5004 in epoch 0,loss=5.041, acc=0.059 (606.032 img/s).
# Finished step 321 of 5004 in epoch 0,loss=5.055, acc=0.027 (641.269 img/s).
# Finished step 322 of 5004 in epoch 0,loss=5.013, acc=0.035 (573.900 img/s).
# Finished step 323 of 5004 in epoch 0,loss=5.020, acc=0.078 (580.976 img/s).
# Finished step 324 of 5004 in epoch 0,loss=5.002, acc=0.055 (602.786 img/s).
# Finished step 325 of 5004 in epoch 0,loss=4.991, acc=0.043 (483.423 img/s).
# Finished step 326 of 5004 in epoch 0,loss=5.163, acc=0.027 (578.760 img/s).
# Finished step 327 of 5004 in epoch 0,loss=5.100, acc=0.031 (630.824 img/s).
# Finished step 328 of 5004 in epoch 0,loss=4.875, acc=0.047 (576.899 img/s).
# Finished step 329 of 5004 in epoch 0,loss=4.890, acc=0.066 (630.012 img/s).
# Finished step 330 of 5004 in epoch 0,loss=5.100, acc=0.051 (639.885 img/s).
# Finished step 331 of 5004 in epoch 0,loss=5.141, acc=0.047 (544.844 img/s).
# Finished step 332 of 5004 in epoch 0,loss=5.009, acc=0.051 (641.541 img/s).
# Finished step 333 of 5004 in epoch 0,loss=4.997, acc=0.039 (650.277 img/s).
# Finished step 334 of 5004 in epoch 0,loss=5.048, acc=0.051 (620.033 img/s).
# Finished step 335 of 5004 in epoch 0,loss=5.091, acc=0.055 (591.400 img/s).
# Finished step 336 of 5004 in epoch 0,loss=5.075, acc=0.035 (647.776 img/s).
# Finished step 337 of 5004 in epoch 0,loss=4.989, acc=0.039 (620.706 img/s).
# Finished step 338 of 5004 in epoch 0,loss=5.077, acc=0.066 (624.995 img/s).
# Finished step 339 of 5004 in epoch 0,loss=4.946, acc=0.074 (589.862 img/s).
# Finished step 340 of 5004 in epoch 0,loss=5.009, acc=0.047 (673.107 img/s).
# Finished step 341 of 5004 in epoch 0,loss=5.080, acc=0.051 (627.460 img/s).
# Finished step 342 of 5004 in epoch 0,loss=5.095, acc=0.047 (599.759 img/s).
# Finished step 343 of 5004 in epoch 0,loss=4.935, acc=0.062 (574.188 img/s).
# Finished step 344 of 5004 in epoch 0,loss=5.261, acc=0.047 (656.718 img/s).
# Finished step 345 of 5004 in epoch 0,loss=5.124, acc=0.023 (615.040 img/s).
# Finished step 346 of 5004 in epoch 0,loss=5.079, acc=0.043 (605.496 img/s).
# Finished step 347 of 5004 in epoch 0,loss=5.058, acc=0.062 (606.811 img/s).
# Finished step 348 of 5004 in epoch 0,loss=4.981, acc=0.055 (549.644 img/s).
# Finished step 349 of 5004 in epoch 0,loss=4.924, acc=0.047 (550.605 img/s).
# Finished step 350 of 5004 in epoch 0,loss=5.095, acc=0.066 (639.354 img/s).
# Finished step 351 of 5004 in epoch 0,loss=5.068, acc=0.062 (660.050 img/s).
# Finished step 352 of 5004 in epoch 0,loss=5.179, acc=0.027 (644.899 img/s).
# Finished step 353 of 5004 in epoch 0,loss=5.050, acc=0.043 (596.825 img/s).
# Finished step 354 of 5004 in epoch 0,loss=5.227, acc=0.047 (658.711 img/s).
# Finished step 355 of 5004 in epoch 0,loss=5.180, acc=0.027 (536.863 img/s).
# Finished step 356 of 5004 in epoch 0,loss=5.165, acc=0.051 (614.190 img/s).
# Finished step 357 of 5004 in epoch 0,loss=5.105, acc=0.062 (587.655 img/s).
# Finished step 358 of 5004 in epoch 0,loss=5.082, acc=0.055 (559.087 img/s).
# Finished step 359 of 5004 in epoch 0,loss=4.990, acc=0.086 (623.737 img/s).
# Finished step 360 of 5004 in epoch 0,loss=5.080, acc=0.031 (614.255 img/s).
# Finished step 361 of 5004 in epoch 0,loss=4.966, acc=0.062 (579.163 img/s).
# Finished step 362 of 5004 in epoch 0,loss=5.096, acc=0.023 (575.530 img/s).
# Finished step 363 of 5004 in epoch 0,loss=5.124, acc=0.039 (550.500 img/s).
# Finished step 364 of 5004 in epoch 0,loss=5.046, acc=0.047 (697.596 img/s).
# Finished step 365 of 5004 in epoch 0,loss=5.099, acc=0.070 (545.461 img/s).
# Finished step 366 of 5004 in epoch 0,loss=4.974, acc=0.043 (638.759 img/s).
# Finished step 367 of 5004 in epoch 0,loss=5.252, acc=0.070 (600.358 img/s).
# Finished step 368 of 5004 in epoch 0,loss=4.933, acc=0.047 (564.748 img/s).
# Finished step 369 of 5004 in epoch 0,loss=4.903, acc=0.059 (662.610 img/s).
# Finished step 370 of 5004 in epoch 0,loss=5.217, acc=0.051 (641.005 img/s).
# Finished step 371 of 5004 in epoch 0,loss=5.019, acc=0.027 (646.352 img/s).
# Finished step 372 of 5004 in epoch 0,loss=5.010, acc=0.051 (640.753 img/s).
# Finished step 373 of 5004 in epoch 0,loss=5.127, acc=0.047 (601.280 img/s).
# Finished step 374 of 5004 in epoch 0,loss=5.230, acc=0.020 (652.733 img/s).
# Finished step 375 of 5004 in epoch 0,loss=5.034, acc=0.074 (599.348 img/s).
# Finished step 376 of 5004 in epoch 0,loss=4.994, acc=0.051 (683.558 img/s).
# Finished step 377 of 5004 in epoch 0,loss=4.908, acc=0.062 (573.301 img/s).
# Finished step 378 of 5004 in epoch 0,loss=4.989, acc=0.059 (610.660 img/s).
# Finished step 379 of 5004 in epoch 0,loss=4.854, acc=0.074 (487.131 img/s).
# Finished step 380 of 5004 in epoch 0,loss=5.007, acc=0.078 (619.650 img/s).
# Finished step 381 of 5004 in epoch 0,loss=5.057, acc=0.055 (610.868 img/s).
# Finished step 382 of 5004 in epoch 0,loss=4.848, acc=0.062 (533.161 img/s).
# Finished step 383 of 5004 in epoch 0,loss=4.972, acc=0.055 (516.427 img/s).
# Finished step 384 of 5004 in epoch 0,loss=5.005, acc=0.035 (618.021 img/s).
# Finished step 385 of 5004 in epoch 0,loss=4.937, acc=0.047 (537.215 img/s).
# Finished step 386 of 5004 in epoch 0,loss=5.149, acc=0.035 (619.374 img/s).
# Finished step 387 of 5004 in epoch 0,loss=5.096, acc=0.051 (640.551 img/s).
# Finished step 388 of 5004 in epoch 0,loss=5.141, acc=0.027 (608.440 img/s).
# Finished step 389 of 5004 in epoch 0,loss=4.875, acc=0.074 (642.890 img/s).
# Finished step 390 of 5004 in epoch 0,loss=5.029, acc=0.035 (653.798 img/s).
# Finished step 391 of 5004 in epoch 0,loss=4.908, acc=0.062 (665.569 img/s).
# Finished step 392 of 5004 in epoch 0,loss=5.082, acc=0.043 (545.667 img/s).
# Finished step 393 of 5004 in epoch 0,loss=4.940, acc=0.047 (649.114 img/s).
# Finished step 394 of 5004 in epoch 0,loss=4.951, acc=0.062 (626.205 img/s).
# Finished step 395 of 5004 in epoch 0,loss=4.858, acc=0.039 (634.566 img/s).
# Finished step 396 of 5004 in epoch 0,loss=4.944, acc=0.055 (522.799 img/s).
# Finished step 397 of 5004 in epoch 0,loss=5.058, acc=0.047 (632.155 img/s).
# Finished step 398 of 5004 in epoch 0,loss=4.957, acc=0.062 (624.112 img/s).
# Finished step 399 of 5004 in epoch 0,loss=5.004, acc=0.047 (625.515 img/s).
# Finished step 400 of 5004 in epoch 0,loss=4.927, acc=0.059 (667.367 img/s).
# Finished step 401 of 5004 in epoch 0,loss=5.081, acc=0.027 (677.843 img/s).
# Finished step 402 of 5004 in epoch 0,loss=5.118, acc=0.059 (554.684 img/s).
# Finished step 403 of 5004 in epoch 0,loss=5.176, acc=0.051 (617.232 img/s).
# Finished step 404 of 5004 in epoch 0,loss=5.072, acc=0.020 (659.567 img/s).
# Finished step 405 of 5004 in epoch 0,loss=5.101, acc=0.074 (603.941 img/s).
# Finished step 406 of 5004 in epoch 0,loss=5.085, acc=0.031 (657.241 img/s).
# Finished step 407 of 5004 in epoch 0,loss=5.088, acc=0.066 (603.814 img/s).
# Finished step 408 of 5004 in epoch 0,loss=5.043, acc=0.051 (583.329 img/s).
# Finished step 409 of 5004 in epoch 0,loss=5.111, acc=0.047 (606.807 img/s).
# Finished step 410 of 5004 in epoch 0,loss=5.097, acc=0.059 (583.835 img/s).
# Finished step 411 of 5004 in epoch 0,loss=5.072, acc=0.047 (602.345 img/s).
# Finished step 412 of 5004 in epoch 0,loss=4.985, acc=0.047 (625.734 img/s).
# Finished step 413 of 5004 in epoch 0,loss=5.105, acc=0.066 (668.443 img/s).
# Finished step 414 of 5004 in epoch 0,loss=4.906, acc=0.047 (655.141 img/s).
# Finished step 415 of 5004 in epoch 0,loss=4.886, acc=0.074 (616.063 img/s).
# Finished step 416 of 5004 in epoch 0,loss=5.010, acc=0.059 (655.603 img/s).
# Finished step 417 of 5004 in epoch 0,loss=4.936, acc=0.082 (635.404 img/s).
# Finished step 418 of 5004 in epoch 0,loss=4.910, acc=0.059 (603.165 img/s).
# Finished step 419 of 5004 in epoch 0,loss=5.153, acc=0.027 (652.384 img/s).
# Finished step 420 of 5004 in epoch 0,loss=4.987, acc=0.051 (626.990 img/s).
# Finished step 421 of 5004 in epoch 0,loss=4.921, acc=0.035 (641.990 img/s).
# Finished step 422 of 5004 in epoch 0,loss=4.982, acc=0.039 (650.709 img/s).
# Finished step 423 of 5004 in epoch 0,loss=5.083, acc=0.059 (575.438 img/s).
# Finished step 424 of 5004 in epoch 0,loss=5.049, acc=0.035 (573.284 img/s).
# Finished step 425 of 5004 in epoch 0,loss=4.995, acc=0.066 (482.216 img/s).
# Finished step 426 of 5004 in epoch 0,loss=5.036, acc=0.051 (573.960 img/s).
# Finished step 427 of 5004 in epoch 0,loss=5.170, acc=0.031 (665.842 img/s).
# Finished step 428 of 5004 in epoch 0,loss=5.103, acc=0.078 (635.602 img/s).
# Finished step 429 of 5004 in epoch 0,loss=5.033, acc=0.059 (662.964 img/s).
# Finished step 430 of 5004 in epoch 0,loss=4.930, acc=0.062 (593.301 img/s).
# Finished step 431 of 5004 in epoch 0,loss=4.984, acc=0.066 (586.703 img/s).
# Finished step 432 of 5004 in epoch 0,loss=5.189, acc=0.039 (632.605 img/s).
# Finished step 433 of 5004 in epoch 0,loss=5.000, acc=0.066 (575.454 img/s).
# Finished step 434 of 5004 in epoch 0,loss=4.829, acc=0.066 (676.519 img/s).
# Finished step 435 of 5004 in epoch 0,loss=4.965, acc=0.078 (637.022 img/s).
# Finished step 436 of 5004 in epoch 0,loss=5.207, acc=0.047 (612.730 img/s).
# Finished step 437 of 5004 in epoch 0,loss=5.029, acc=0.074 (625.300 img/s).
# Finished step 438 of 5004 in epoch 0,loss=4.998, acc=0.051 (615.766 img/s).
# Finished step 439 of 5004 in epoch 0,loss=5.148, acc=0.031 (667.989 img/s).
# Finished step 440 of 5004 in epoch 0,loss=4.886, acc=0.070 (673.813 img/s).
# Finished step 441 of 5004 in epoch 0,loss=5.062, acc=0.031 (622.360 img/s).
# Finished step 442 of 5004 in epoch 0,loss=5.040, acc=0.062 (540.537 img/s).
# Finished step 443 of 5004 in epoch 0,loss=4.978, acc=0.031 (586.211 img/s).
# Finished step 444 of 5004 in epoch 0,loss=4.975, acc=0.047 (617.935 img/s).
# Finished step 445 of 5004 in epoch 0,loss=5.018, acc=0.043 (630.116 img/s).
# Finished step 446 of 5004 in epoch 0,loss=5.005, acc=0.047 (645.978 img/s).
# Finished step 447 of 5004 in epoch 0,loss=5.001, acc=0.051 (653.503 img/s).
# Finished step 448 of 5004 in epoch 0,loss=5.125, acc=0.043 (599.133 img/s).
# Finished step 449 of 5004 in epoch 0,loss=4.696, acc=0.066 (650.509 img/s).
# Finished step 450 of 5004 in epoch 0,loss=5.055, acc=0.027 (621.391 img/s).
# Finished step 451 of 5004 in epoch 0,loss=5.010, acc=0.055 (658.918 img/s).
# Finished step 452 of 5004 in epoch 0,loss=5.172, acc=0.051 (622.987 img/s).
# Finished step 453 of 5004 in epoch 0,loss=4.990, acc=0.047 (570.423 img/s).
# Finished step 454 of 5004 in epoch 0,loss=5.092, acc=0.035 (641.033 img/s).
# Finished step 455 of 5004 in epoch 0,loss=4.997, acc=0.035 (587.371 img/s).
# Finished step 456 of 5004 in epoch 0,loss=5.029, acc=0.059 (668.788 img/s).
# Finished step 457 of 5004 in epoch 0,loss=5.015, acc=0.035 (183.924 img/s).
# Finished step 458 of 5004 in epoch 0,loss=5.159, acc=0.027 (643.212 img/s).
# Finished step 459 of 5004 in epoch 0,loss=5.177, acc=0.059 (590.703 img/s).
# Finished step 460 of 5004 in epoch 0,loss=5.094, acc=0.035 (673.693 img/s).
# Finished step 461 of 5004 in epoch 0,loss=4.933, acc=0.047 (626.768 img/s).
# Finished step 462 of 5004 in epoch 0,loss=5.086, acc=0.047 (683.045 img/s).
# Finished step 463 of 5004 in epoch 0,loss=4.939, acc=0.047 (633.129 img/s).
# Finished step 464 of 5004 in epoch 0,loss=5.002, acc=0.055 (583.302 img/s).
# Finished step 465 of 5004 in epoch 0,loss=5.058, acc=0.023 (640.220 img/s).
# Finished step 466 of 5004 in epoch 0,loss=5.077, acc=0.055 (633.280 img/s).
# Finished step 467 of 5004 in epoch 0,loss=4.952, acc=0.062 (675.356 img/s).
# Finished step 468 of 5004 in epoch 0,loss=5.066, acc=0.070 (645.279 img/s).
# Finished step 469 of 5004 in epoch 0,loss=5.073, acc=0.035 (642.204 img/s).
# Finished step 470 of 5004 in epoch 0,loss=5.015, acc=0.047 (690.468 img/s).
# Finished step 471 of 5004 in epoch 0,loss=5.101, acc=0.043 (656.471 img/s).
# Finished step 472 of 5004 in epoch 0,loss=5.144, acc=0.023 (606.038 img/s).
# Finished step 473 of 5004 in epoch 0,loss=5.186, acc=0.039 (663.162 img/s).
# Finished step 474 of 5004 in epoch 0,loss=5.232, acc=0.051 (621.806 img/s).
# Finished step 475 of 5004 in epoch 0,loss=5.034, acc=0.051 (550.480 img/s).
# Finished step 476 of 5004 in epoch 0,loss=5.112, acc=0.051 (674.523 img/s).
# Finished step 477 of 5004 in epoch 0,loss=5.225, acc=0.027 (651.877 img/s).
# Finished step 478 of 5004 in epoch 0,loss=5.173, acc=0.047 (569.378 img/s).
# Finished step 479 of 5004 in epoch 0,loss=5.152, acc=0.055 (557.634 img/s).
# Finished step 480 of 5004 in epoch 0,loss=5.133, acc=0.074 (652.536 img/s).
# Finished step 481 of 5004 in epoch 0,loss=5.074, acc=0.039 (674.711 img/s).
# Finished step 482 of 5004 in epoch 0,loss=5.034, acc=0.059 (660.046 img/s).
# Finished step 483 of 5004 in epoch 0,loss=4.887, acc=0.066 (644.676 img/s).
# Finished step 484 of 5004 in epoch 0,loss=5.086, acc=0.066 (689.510 img/s).
# Finished step 485 of 5004 in epoch 0,loss=5.031, acc=0.066 (633.289 img/s).
# Finished step 486 of 5004 in epoch 0,loss=5.080, acc=0.094 (630.593 img/s).
# Finished step 487 of 5004 in epoch 0,loss=5.151, acc=0.051 (581.669 img/s).
# Finished step 488 of 5004 in epoch 0,loss=5.152, acc=0.047 (660.081 img/s).
# Finished step 489 of 5004 in epoch 0,loss=5.007, acc=0.062 (507.490 img/s).
# Finished step 490 of 5004 in epoch 0,loss=5.064, acc=0.055 (622.952 img/s).
# Finished step 491 of 5004 in epoch 0,loss=5.038, acc=0.070 (636.097 img/s).
# Finished step 492 of 5004 in epoch 0,loss=5.047, acc=0.062 (676.306 img/s).
# Finished step 493 of 5004 in epoch 0,loss=4.927, acc=0.066 (592.606 img/s).
# Finished step 494 of 5004 in epoch 0,loss=5.126, acc=0.039 (636.747 img/s).
# Finished step 495 of 5004 in epoch 0,loss=4.957, acc=0.078 (621.607 img/s).
# Finished step 496 of 5004 in epoch 0,loss=5.002, acc=0.059 (622.477 img/s).
# Finished step 497 of 5004 in epoch 0,loss=5.066, acc=0.051 (558.388 img/s).
# Finished step 498 of 5004 in epoch 0,loss=5.044, acc=0.035 (689.658 img/s).
# Finished step 499 of 5004 in epoch 0,loss=4.990, acc=0.031 (667.476 img/s).
# Finished step 500 of 5004 in epoch 0,loss=4.965, acc=0.051 (652.922 img/s).
# Finished step 501 of 5004 in epoch 0,loss=5.015, acc=0.066 (638.721 img/s).
# Finished step 502 of 5004 in epoch 0,loss=4.926, acc=0.059 (571.476 img/s).
# Finished step 503 of 5004 in epoch 0,loss=4.873, acc=0.035 (644.417 img/s).
# Finished step 504 of 5004 in epoch 0,loss=4.868, acc=0.062 (669.619 img/s).
# Finished step 505 of 5004 in epoch 0,loss=4.978, acc=0.059 (579.415 img/s).
# Finished step 506 of 5004 in epoch 0,loss=5.020, acc=0.043 (675.636 img/s).
# Finished step 507 of 5004 in epoch 0,loss=5.077, acc=0.086 (515.975 img/s).
# Finished step 508 of 5004 in epoch 0,loss=4.866, acc=0.098 (586.944 img/s).
# Finished step 509 of 5004 in epoch 0,loss=4.973, acc=0.051 (570.996 img/s).
# Finished step 510 of 5004 in epoch 0,loss=5.071, acc=0.031 (615.272 img/s).
# Finished step 511 of 5004 in epoch 0,loss=5.102, acc=0.043 (597.987 img/s).
# Finished step 512 of 5004 in epoch 0,loss=4.972, acc=0.059 (569.855 img/s).
# Finished step 513 of 5004 in epoch 0,loss=5.098, acc=0.059 (658.438 img/s).
# Finished step 514 of 5004 in epoch 0,loss=4.963, acc=0.051 (581.227 img/s).
# Finished step 515 of 5004 in epoch 0,loss=4.970, acc=0.074 (639.996 img/s).
# Finished step 516 of 5004 in epoch 0,loss=5.211, acc=0.090 (632.422 img/s).
# Finished step 517 of 5004 in epoch 0,loss=5.046, acc=0.078 (561.173 img/s).
# Finished step 518 of 5004 in epoch 0,loss=4.941, acc=0.051 (661.123 img/s).
# Finished step 519 of 5004 in epoch 0,loss=5.092, acc=0.070 (607.142 img/s).
# Finished step 520 of 5004 in epoch 0,loss=5.122, acc=0.039 (645.869 img/s).
# Finished step 521 of 5004 in epoch 0,loss=5.110, acc=0.059 (620.493 img/s).
# Finished step 522 of 5004 in epoch 0,loss=4.953, acc=0.066 (541.419 img/s).
# Finished step 523 of 5004 in epoch 0,loss=4.871, acc=0.062 (606.587 img/s).
# Finished step 524 of 5004 in epoch 0,loss=4.918, acc=0.051 (596.286 img/s).
# Finished step 525 of 5004 in epoch 0,loss=5.110, acc=0.035 (656.523 img/s).
# Finished step 526 of 5004 in epoch 0,loss=4.911, acc=0.078 (660.686 img/s).
# Finished step 527 of 5004 in epoch 0,loss=5.040, acc=0.051 (598.569 img/s).
# Finished step 528 of 5004 in epoch 0,loss=5.012, acc=0.059 (583.563 img/s).
# Finished step 529 of 5004 in epoch 0,loss=5.071, acc=0.047 (575.152 img/s).
# Finished step 530 of 5004 in epoch 0,loss=5.080, acc=0.090 (607.373 img/s).
# Finished step 531 of 5004 in epoch 0,loss=5.040, acc=0.047 (548.930 img/s).
# Finished step 532 of 5004 in epoch 0,loss=4.907, acc=0.062 (664.203 img/s).
# Finished step 533 of 5004 in epoch 0,loss=5.087, acc=0.051 (564.913 img/s).
# Finished step 534 of 5004 in epoch 0,loss=5.150, acc=0.051 (673.146 img/s).
# Finished step 535 of 5004 in epoch 0,loss=5.292, acc=0.062 (661.229 img/s).
# Finished step 536 of 5004 in epoch 0,loss=5.196, acc=0.047 (684.371 img/s).
# Finished step 537 of 5004 in epoch 0,loss=5.088, acc=0.047 (619.336 img/s).
# Finished step 538 of 5004 in epoch 0,loss=5.079, acc=0.047 (640.503 img/s).
# Finished step 539 of 5004 in epoch 0,loss=5.275, acc=0.039 (644.426 img/s).
# Finished step 540 of 5004 in epoch 0,loss=5.198, acc=0.051 (655.545 img/s).
# Finished step 541 of 5004 in epoch 0,loss=5.019, acc=0.078 (652.616 img/s).
# Finished step 542 of 5004 in epoch 0,loss=5.104, acc=0.070 (637.572 img/s).
# Finished step 543 of 5004 in epoch 0,loss=5.002, acc=0.055 (594.968 img/s).
# Finished step 544 of 5004 in epoch 0,loss=4.969, acc=0.059 (657.005 img/s).
# Finished step 545 of 5004 in epoch 0,loss=5.239, acc=0.051 (629.648 img/s).
# Finished step 546 of 5004 in epoch 0,loss=5.112, acc=0.062 (529.393 img/s).
# Finished step 547 of 5004 in epoch 0,loss=4.956, acc=0.082 (640.705 img/s).
# Finished step 548 of 5004 in epoch 0,loss=5.091, acc=0.047 (527.740 img/s).
# Finished step 549 of 5004 in epoch 0,loss=5.159, acc=0.059 (633.683 img/s).
# Finished step 550 of 5004 in epoch 0,loss=5.010, acc=0.062 (470.426 img/s).
# Finished step 551 of 5004 in epoch 0,loss=5.097, acc=0.059 (669.624 img/s).
# Finished step 552 of 5004 in epoch 0,loss=5.194, acc=0.059 (659.685 img/s).
# Finished step 553 of 5004 in epoch 0,loss=4.955, acc=0.070 (644.670 img/s).
# Finished step 554 of 5004 in epoch 0,loss=5.144, acc=0.031 (658.253 img/s).
# Finished step 555 of 5004 in epoch 0,loss=5.164, acc=0.039 (616.953 img/s).
# Finished step 556 of 5004 in epoch 0,loss=5.023, acc=0.062 (559.928 img/s).
# Finished step 557 of 5004 in epoch 0,loss=5.051, acc=0.047 (655.613 img/s).
# Finished step 558 of 5004 in epoch 0,loss=5.311, acc=0.035 (616.311 img/s).
# Finished step 559 of 5004 in epoch 0,loss=5.175, acc=0.027 (502.837 img/s).
# Finished step 560 of 5004 in epoch 0,loss=5.061, acc=0.055 (649.952 img/s).
# Finished step 561 of 5004 in epoch 0,loss=5.063, acc=0.031 (639.088 img/s).
# Finished step 562 of 5004 in epoch 0,loss=5.094, acc=0.055 (619.267 img/s).
# Finished step 563 of 5004 in epoch 0,loss=5.188, acc=0.020 (631.231 img/s).
# Finished step 564 of 5004 in epoch 0,loss=5.139, acc=0.051 (640.624 img/s).
# Finished step 565 of 5004 in epoch 0,loss=5.040, acc=0.074 (598.311 img/s).
# Finished step 566 of 5004 in epoch 0,loss=5.088, acc=0.090 (687.317 img/s).
# Finished step 567 of 5004 in epoch 0,loss=5.127, acc=0.023 (643.644 img/s).
# Finished step 568 of 5004 in epoch 0,loss=5.176, acc=0.031 (641.848 img/s).
# Finished step 569 of 5004 in epoch 0,loss=4.987, acc=0.043 (566.490 img/s).
# Finished step 570 of 5004 in epoch 0,loss=5.001, acc=0.062 (677.274 img/s).
# Finished step 571 of 5004 in epoch 0,loss=5.279, acc=0.047 (660.517 img/s).
# Finished step 572 of 5004 in epoch 0,loss=5.018, acc=0.090 (684.405 img/s).
# Finished step 573 of 5004 in epoch 0,loss=5.220, acc=0.043 (508.954 img/s).
# Finished step 574 of 5004 in epoch 0,loss=4.955, acc=0.055 (633.187 img/s).
# Finished step 575 of 5004 in epoch 0,loss=5.082, acc=0.078 (582.489 img/s).
# Finished step 576 of 5004 in epoch 0,loss=5.104, acc=0.055 (699.309 img/s).
# Finished step 577 of 5004 in epoch 0,loss=4.976, acc=0.059 (690.227 img/s).
# Finished step 578 of 5004 in epoch 0,loss=5.064, acc=0.062 (712.498 img/s).
# Finished step 579 of 5004 in epoch 0,loss=5.044, acc=0.090 (582.932 img/s).
# Finished step 580 of 5004 in epoch 0,loss=4.913, acc=0.051 (675.546 img/s).
# Finished step 581 of 5004 in epoch 0,loss=5.012, acc=0.066 (692.777 img/s).
# Finished step 582 of 5004 in epoch 0,loss=5.176, acc=0.066 (621.851 img/s).
# Finished step 583 of 5004 in epoch 0,loss=5.059, acc=0.051 (631.617 img/s).
# Finished step 584 of 5004 in epoch 0,loss=4.963, acc=0.070 (527.431 img/s).
# Finished step 585 of 5004 in epoch 0,loss=5.064, acc=0.047 (653.896 img/s).
# Finished step 586 of 5004 in epoch 0,loss=5.166, acc=0.051 (641.434 img/s).
# Finished step 587 of 5004 in epoch 0,loss=4.984, acc=0.062 (640.312 img/s).
# Finished step 588 of 5004 in epoch 0,loss=5.178, acc=0.066 (549.496 img/s).
# ...
# Finished step 4798 of 5004 in epoch 0,loss=3.684, acc=0.238 (709.050 img/s).
# Finished step 4799 of 5004 in epoch 0,loss=3.876, acc=0.227 (669.727 img/s).
# Finished step 4800 of 5004 in epoch 0,loss=3.812, acc=0.219 (683.383 img/s).
# Finished step 4801 of 5004 in epoch 0,loss=3.963, acc=0.230 (715.893 img/s).
# Finished step 4802 of 5004 in epoch 0,loss=3.880, acc=0.207 (701.119 img/s).
# Finished step 4803 of 5004 in epoch 0,loss=4.040, acc=0.199 (726.033 img/s).
# Finished step 4804 of 5004 in epoch 0,loss=3.842, acc=0.219 (657.525 img/s).
# Finished step 4805 of 5004 in epoch 0,loss=3.790, acc=0.250 (687.140 img/s).
# Finished step 4806 of 5004 in epoch 0,loss=3.750, acc=0.238 (636.639 img/s).
# Finished step 4807 of 5004 in epoch 0,loss=3.680, acc=0.250 (715.385 img/s).
# Finished step 4808 of 5004 in epoch 0,loss=3.567, acc=0.266 (716.021 img/s).
# Finished step 4809 of 5004 in epoch 0,loss=4.014, acc=0.250 (640.695 img/s).
# Finished step 4810 of 5004 in epoch 0,loss=3.757, acc=0.211 (748.493 img/s).
# Finished step 4811 of 5004 in epoch 0,loss=3.617, acc=0.215 (614.171 img/s).
# Finished step 4812 of 5004 in epoch 0,loss=3.739, acc=0.270 (714.629 img/s).
# Finished step 4813 of 5004 in epoch 0,loss=3.810, acc=0.164 (703.654 img/s).
# Finished step 4814 of 5004 in epoch 0,loss=4.170, acc=0.199 (629.476 img/s).
# Finished step 4815 of 5004 in epoch 0,loss=3.502, acc=0.305 (702.388 img/s).
# Finished step 4816 of 5004 in epoch 0,loss=3.907, acc=0.219 (714.626 img/s).
# Finished step 4817 of 5004 in epoch 0,loss=3.723, acc=0.270 (587.595 img/s).
# Finished step 4818 of 5004 in epoch 0,loss=3.702, acc=0.258 (703.171 img/s).
# Finished step 4819 of 5004 in epoch 0,loss=3.872, acc=0.246 (673.175 img/s).
# Finished step 4820 of 5004 in epoch 0,loss=3.908, acc=0.238 (658.946 img/s).
# Finished step 4821 of 5004 in epoch 0,loss=3.755, acc=0.246 (720.801 img/s).
# Finished step 4822 of 5004 in epoch 0,loss=3.817, acc=0.270 (716.059 img/s).
# Finished step 4823 of 5004 in epoch 0,loss=3.734, acc=0.215 (745.318 img/s).
# Finished step 4824 of 5004 in epoch 0,loss=4.007, acc=0.207 (487.144 img/s).
# Finished step 4825 of 5004 in epoch 0,loss=4.025, acc=0.176 (708.261 img/s).
# Finished step 4826 of 5004 in epoch 0,loss=3.780, acc=0.238 (740.369 img/s).
# Finished step 4827 of 5004 in epoch 0,loss=3.855, acc=0.250 (645.937 img/s).
# Finished step 4828 of 5004 in epoch 0,loss=3.980, acc=0.172 (731.285 img/s).
# Finished step 4829 of 5004 in epoch 0,loss=3.989, acc=0.191 (783.631 img/s).
# Finished step 4830 of 5004 in epoch 0,loss=3.727, acc=0.246 (652.794 img/s).
# Finished step 4831 of 5004 in epoch 0,loss=3.572, acc=0.258 (770.652 img/s).
# Finished step 4832 of 5004 in epoch 0,loss=3.877, acc=0.211 (657.722 img/s).
# Finished step 4833 of 5004 in epoch 0,loss=3.899, acc=0.234 (668.922 img/s).
# Finished step 4834 of 5004 in epoch 0,loss=3.914, acc=0.207 (632.611 img/s).
# Finished step 4835 of 5004 in epoch 0,loss=3.654, acc=0.215 (675.640 img/s).
# Finished step 4836 of 5004 in epoch 0,loss=3.874, acc=0.203 (751.181 img/s).
# Finished step 4837 of 5004 in epoch 0,loss=4.006, acc=0.191 (625.645 img/s).
# Finished step 4838 of 5004 in epoch 0,loss=3.781, acc=0.215 (701.759 img/s).
# Finished step 4839 of 5004 in epoch 0,loss=3.779, acc=0.254 (771.096 img/s).
# Finished step 4840 of 5004 in epoch 0,loss=3.658, acc=0.270 (744.140 img/s).
# Finished step 4841 of 5004 in epoch 0,loss=3.813, acc=0.227 (686.884 img/s).
# Finished step 4842 of 5004 in epoch 0,loss=3.476, acc=0.242 (586.710 img/s).
# Finished step 4843 of 5004 in epoch 0,loss=3.771, acc=0.254 (666.089 img/s).
# Finished step 4844 of 5004 in epoch 0,loss=3.816, acc=0.215 (756.190 img/s).
# Finished step 4845 of 5004 in epoch 0,loss=3.765, acc=0.219 (699.435 img/s).
# Finished step 4846 of 5004 in epoch 0,loss=3.822, acc=0.234 (574.969 img/s).
# Finished step 4847 of 5004 in epoch 0,loss=3.912, acc=0.223 (742.451 img/s).
# Finished step 4848 of 5004 in epoch 0,loss=3.830, acc=0.227 (751.328 img/s).
# Finished step 4849 of 5004 in epoch 0,loss=3.914, acc=0.242 (695.087 img/s).
# Finished step 4850 of 5004 in epoch 0,loss=3.779, acc=0.238 (567.698 img/s).
# Finished step 4851 of 5004 in epoch 0,loss=3.518, acc=0.320 (744.717 img/s).
# Finished step 4852 of 5004 in epoch 0,loss=3.568, acc=0.258 (650.035 img/s).
# Finished step 4853 of 5004 in epoch 0,loss=3.493, acc=0.234 (688.481 img/s).
# Finished step 4854 of 5004 in epoch 0,loss=3.795, acc=0.219 (745.335 img/s).
# Finished step 4855 of 5004 in epoch 0,loss=3.716, acc=0.234 (746.958 img/s).
# Finished step 4856 of 5004 in epoch 0,loss=3.949, acc=0.207 (622.582 img/s).
# Finished step 4857 of 5004 in epoch 0,loss=3.617, acc=0.242 (669.611 img/s).
# Finished step 4858 of 5004 in epoch 0,loss=3.626, acc=0.266 (771.883 img/s).
# Finished step 4859 of 5004 in epoch 0,loss=3.850, acc=0.234 (651.906 img/s).
# Finished step 4860 of 5004 in epoch 0,loss=3.927, acc=0.223 (707.809 img/s).
# Finished step 4861 of 5004 in epoch 0,loss=3.783, acc=0.207 (694.190 img/s).
# Finished step 4862 of 5004 in epoch 0,loss=3.742, acc=0.266 (729.390 img/s).
# Finished step 4863 of 5004 in epoch 0,loss=3.882, acc=0.238 (572.226 img/s).
# Finished step 4864 of 5004 in epoch 0,loss=3.886, acc=0.230 (692.940 img/s).
# Finished step 4865 of 5004 in epoch 0,loss=3.920, acc=0.223 (751.344 img/s).
# Finished step 4866 of 5004 in epoch 0,loss=3.732, acc=0.238 (573.243 img/s).
# Finished step 4867 of 5004 in epoch 0,loss=3.817, acc=0.215 (780.433 img/s).
# Finished step 4868 of 5004 in epoch 0,loss=3.683, acc=0.266 (700.147 img/s).
# Finished step 4869 of 5004 in epoch 0,loss=3.903, acc=0.223 (739.545 img/s).
# Finished step 4870 of 5004 in epoch 0,loss=4.022, acc=0.219 (734.340 img/s).
# Finished step 4871 of 5004 in epoch 0,loss=3.676, acc=0.270 (671.459 img/s).
# Finished step 4872 of 5004 in epoch 0,loss=3.854, acc=0.227 (701.341 img/s).
# Finished step 4873 of 5004 in epoch 0,loss=3.628, acc=0.223 (676.558 img/s).
# Finished step 4874 of 5004 in epoch 0,loss=3.796, acc=0.246 (743.025 img/s).
# Finished step 4875 of 5004 in epoch 0,loss=3.876, acc=0.277 (717.663 img/s).
# Finished step 4876 of 5004 in epoch 0,loss=3.988, acc=0.176 (695.882 img/s).
# Finished step 4877 of 5004 in epoch 0,loss=3.927, acc=0.234 (676.855 img/s).
# Finished step 4878 of 5004 in epoch 0,loss=3.500, acc=0.273 (680.745 img/s).
# Finished step 4879 of 5004 in epoch 0,loss=3.924, acc=0.227 (744.116 img/s).
# Finished step 4880 of 5004 in epoch 0,loss=3.967, acc=0.195 (655.822 img/s).
# Finished step 4881 of 5004 in epoch 0,loss=3.651, acc=0.250 (687.575 img/s).
# Finished step 4882 of 5004 in epoch 0,loss=3.988, acc=0.219 (677.901 img/s).
# Finished step 4883 of 5004 in epoch 0,loss=3.590, acc=0.273 (734.365 img/s).
# Finished step 4884 of 5004 in epoch 0,loss=3.812, acc=0.207 (720.605 img/s).
# Finished step 4885 of 5004 in epoch 0,loss=3.781, acc=0.270 (671.871 img/s).
# Finished step 4886 of 5004 in epoch 0,loss=3.930, acc=0.191 (708.560 img/s).
# Finished step 4887 of 5004 in epoch 0,loss=3.745, acc=0.230 (674.120 img/s).
# Finished step 4888 of 5004 in epoch 0,loss=3.901, acc=0.258 (669.821 img/s).
# Finished step 4889 of 5004 in epoch 0,loss=3.754, acc=0.242 (709.256 img/s).
# Finished step 4890 of 5004 in epoch 0,loss=3.703, acc=0.246 (736.450 img/s).
# Finished step 4891 of 5004 in epoch 0,loss=3.750, acc=0.223 (721.357 img/s).
# Finished step 4892 of 5004 in epoch 0,loss=3.638, acc=0.273 (706.869 img/s).
# Finished step 4893 of 5004 in epoch 0,loss=3.736, acc=0.238 (724.210 img/s).
# Finished step 4894 of 5004 in epoch 0,loss=3.890, acc=0.227 (693.295 img/s).
# Finished step 4895 of 5004 in epoch 0,loss=3.700, acc=0.285 (669.288 img/s).
# Finished step 4896 of 5004 in epoch 0,loss=3.780, acc=0.266 (620.757 img/s).
# Finished step 4897 of 5004 in epoch 0,loss=3.411, acc=0.270 (716.226 img/s).
# Finished step 4898 of 5004 in epoch 0,loss=3.512, acc=0.277 (732.006 img/s).
# Finished step 4899 of 5004 in epoch 0,loss=3.635, acc=0.238 (764.615 img/s).
# Finished step 4900 of 5004 in epoch 0,loss=3.776, acc=0.250 (727.427 img/s).
# Finished step 4901 of 5004 in epoch 0,loss=3.600, acc=0.246 (790.351 img/s).
# Finished step 4902 of 5004 in epoch 0,loss=4.050, acc=0.215 (714.186 img/s).
# Finished step 4903 of 5004 in epoch 0,loss=3.720, acc=0.250 (586.043 img/s).
# Finished step 4904 of 5004 in epoch 0,loss=3.895, acc=0.238 (546.899 img/s).
# Finished step 4905 of 5004 in epoch 0,loss=3.900, acc=0.219 (710.750 img/s).
# Finished step 4906 of 5004 in epoch 0,loss=3.624, acc=0.285 (757.473 img/s).
# Finished step 4907 of 5004 in epoch 0,loss=3.851, acc=0.230 (411.003 img/s).
# Finished step 4908 of 5004 in epoch 0,loss=3.764, acc=0.211 (582.645 img/s).
# Finished step 4909 of 5004 in epoch 0,loss=3.620, acc=0.289 (590.645 img/s).
# Finished step 4910 of 5004 in epoch 0,loss=3.506, acc=0.281 (590.751 img/s).
# Finished step 4911 of 5004 in epoch 0,loss=3.766, acc=0.230 (591.756 img/s).
# Finished step 4912 of 5004 in epoch 0,loss=3.648, acc=0.273 (633.569 img/s).
# Finished step 4913 of 5004 in epoch 0,loss=3.935, acc=0.195 (588.112 img/s).
# Finished step 4914 of 5004 in epoch 0,loss=3.969, acc=0.238 (646.834 img/s).
# Finished step 4915 of 5004 in epoch 0,loss=3.932, acc=0.223 (517.593 img/s).
# Finished step 4916 of 5004 in epoch 0,loss=3.636, acc=0.238 (637.850 img/s).
# Finished step 4917 of 5004 in epoch 0,loss=3.764, acc=0.246 (621.429 img/s).
# Finished step 4918 of 5004 in epoch 0,loss=3.797, acc=0.246 (700.805 img/s).
# Finished step 4919 of 5004 in epoch 0,loss=3.673, acc=0.230 (725.321 img/s).
# Finished step 4920 of 5004 in epoch 0,loss=3.893, acc=0.234 (730.665 img/s).
# Finished step 4921 of 5004 in epoch 0,loss=3.724, acc=0.273 (670.515 img/s).
# Finished step 4922 of 5004 in epoch 0,loss=3.823, acc=0.246 (723.798 img/s).
# Finished step 4923 of 5004 in epoch 0,loss=3.448, acc=0.301 (675.773 img/s).
# Finished step 4924 of 5004 in epoch 0,loss=3.688, acc=0.258 (755.257 img/s).
# Finished step 4925 of 5004 in epoch 0,loss=3.554, acc=0.250 (745.578 img/s).
# Finished step 4926 of 5004 in epoch 0,loss=3.601, acc=0.273 (663.424 img/s).
# Finished step 4927 of 5004 in epoch 0,loss=3.691, acc=0.246 (553.368 img/s).
# Finished step 4928 of 5004 in epoch 0,loss=3.627, acc=0.262 (684.772 img/s).
# Finished step 4929 of 5004 in epoch 0,loss=3.910, acc=0.238 (748.947 img/s).
# Finished step 4930 of 5004 in epoch 0,loss=3.554, acc=0.285 (716.442 img/s).
# Finished step 4931 of 5004 in epoch 0,loss=3.801, acc=0.250 (710.967 img/s).
# Finished step 4932 of 5004 in epoch 0,loss=3.632, acc=0.273 (705.231 img/s).
# Finished step 4933 of 5004 in epoch 0,loss=3.831, acc=0.270 (653.987 img/s).
# Finished step 4934 of 5004 in epoch 0,loss=3.802, acc=0.277 (717.179 img/s).
# Finished step 4935 of 5004 in epoch 0,loss=3.814, acc=0.230 (591.652 img/s).
# Finished step 4936 of 5004 in epoch 0,loss=3.554, acc=0.270 (680.894 img/s).
# Finished step 4937 of 5004 in epoch 0,loss=3.704, acc=0.234 (677.690 img/s).
# Finished step 4938 of 5004 in epoch 0,loss=3.811, acc=0.234 (720.452 img/s).
# Finished step 4939 of 5004 in epoch 0,loss=4.085, acc=0.180 (689.556 img/s).
# Finished step 4940 of 5004 in epoch 0,loss=3.773, acc=0.211 (688.195 img/s).
# Finished step 4941 of 5004 in epoch 0,loss=3.728, acc=0.246 (675.190 img/s).
# Finished step 4942 of 5004 in epoch 0,loss=3.674, acc=0.262 (716.519 img/s).
# Finished step 4943 of 5004 in epoch 0,loss=3.727, acc=0.234 (675.155 img/s).
# Finished step 4944 of 5004 in epoch 0,loss=3.669, acc=0.227 (729.083 img/s).
# Finished step 4945 of 5004 in epoch 0,loss=3.579, acc=0.250 (689.430 img/s).
# Finished step 4946 of 5004 in epoch 0,loss=3.738, acc=0.250 (732.070 img/s).
# Finished step 4947 of 5004 in epoch 0,loss=3.748, acc=0.266 (728.779 img/s).
# Finished step 4948 of 5004 in epoch 0,loss=3.810, acc=0.246 (734.317 img/s).
# Finished step 4949 of 5004 in epoch 0,loss=3.596, acc=0.270 (711.860 img/s).
# Finished step 4950 of 5004 in epoch 0,loss=3.436, acc=0.273 (709.262 img/s).
# Finished step 4951 of 5004 in epoch 0,loss=3.707, acc=0.242 (658.139 img/s).
# Finished step 4952 of 5004 in epoch 0,loss=3.738, acc=0.250 (716.371 img/s).
# Finished step 4953 of 5004 in epoch 0,loss=3.668, acc=0.254 (697.598 img/s).
# Finished step 4954 of 5004 in epoch 0,loss=3.557, acc=0.270 (663.272 img/s).
# Finished step 4955 of 5004 in epoch 0,loss=3.655, acc=0.277 (669.327 img/s).
# Finished step 4956 of 5004 in epoch 0,loss=3.603, acc=0.266 (732.089 img/s).
# Finished step 4957 of 5004 in epoch 0,loss=3.530, acc=0.320 (675.461 img/s).
# Finished step 4958 of 5004 in epoch 0,loss=3.714, acc=0.262 (718.619 img/s).
# Finished step 4959 of 5004 in epoch 0,loss=3.594, acc=0.262 (724.451 img/s).
# Finished step 4960 of 5004 in epoch 0,loss=3.710, acc=0.238 (686.454 img/s).
# Finished step 4961 of 5004 in epoch 0,loss=3.804, acc=0.227 (739.988 img/s).
# Finished step 4962 of 5004 in epoch 0,loss=3.639, acc=0.250 (743.883 img/s).
# Finished step 4963 of 5004 in epoch 0,loss=3.634, acc=0.258 (668.529 img/s).
# Finished step 4964 of 5004 in epoch 0,loss=3.689, acc=0.230 (725.735 img/s).
# Finished step 4965 of 5004 in epoch 0,loss=3.796, acc=0.176 (752.148 img/s).
# Finished step 4966 of 5004 in epoch 0,loss=3.689, acc=0.242 (527.581 img/s).
# Finished step 4967 of 5004 in epoch 0,loss=3.263, acc=0.332 (737.980 img/s).
# Finished step 4968 of 5004 in epoch 0,loss=3.606, acc=0.273 (668.726 img/s).
# Finished step 4969 of 5004 in epoch 0,loss=3.774, acc=0.266 (719.688 img/s).
# Finished step 4970 of 5004 in epoch 0,loss=3.737, acc=0.246 (765.659 img/s).
# Finished step 4971 of 5004 in epoch 0,loss=3.685, acc=0.297 (659.011 img/s).
# Finished step 4972 of 5004 in epoch 0,loss=3.529, acc=0.301 (741.658 img/s).
# Finished step 4973 of 5004 in epoch 0,loss=3.436, acc=0.305 (740.071 img/s).
# Finished step 4974 of 5004 in epoch 0,loss=3.659, acc=0.293 (646.188 img/s).
# Finished step 4975 of 5004 in epoch 0,loss=3.723, acc=0.262 (666.879 img/s).
# Finished step 4976 of 5004 in epoch 0,loss=3.650, acc=0.293 (714.246 img/s).
# Finished step 4977 of 5004 in epoch 0,loss=3.744, acc=0.211 (729.628 img/s).
# Finished step 4978 of 5004 in epoch 0,loss=3.653, acc=0.234 (703.657 img/s).
# Finished step 4979 of 5004 in epoch 0,loss=3.583, acc=0.223 (749.321 img/s).
# Finished step 4980 of 5004 in epoch 0,loss=3.981, acc=0.203 (711.457 img/s).
# Finished step 4981 of 5004 in epoch 0,loss=3.706, acc=0.242 (643.786 img/s).
# Finished step 4982 of 5004 in epoch 0,loss=3.656, acc=0.250 (734.598 img/s).
# Finished step 4983 of 5004 in epoch 0,loss=3.658, acc=0.258 (708.870 img/s).
# Finished step 4984 of 5004 in epoch 0,loss=3.414, acc=0.293 (767.462 img/s).
# Finished step 4985 of 5004 in epoch 0,loss=3.352, acc=0.289 (684.725 img/s).
# Finished step 4986 of 5004 in epoch 0,loss=3.434, acc=0.316 (643.440 img/s).
# Finished step 4987 of 5004 in epoch 0,loss=3.601, acc=0.254 (515.375 img/s).
# Finished step 4988 of 5004 in epoch 0,loss=3.493, acc=0.266 (692.800 img/s).
# Finished step 4989 of 5004 in epoch 0,loss=3.939, acc=0.254 (734.632 img/s).
# Finished step 4990 of 5004 in epoch 0,loss=3.590, acc=0.293 (726.410 img/s).
# Finished step 4991 of 5004 in epoch 0,loss=3.528, acc=0.281 (765.576 img/s).
# Finished step 4992 of 5004 in epoch 0,loss=3.892, acc=0.254 (728.064 img/s).
# Finished step 4993 of 5004 in epoch 0,loss=3.699, acc=0.250 (742.587 img/s).
# Finished step 4994 of 5004 in epoch 0,loss=3.569, acc=0.262 (556.498 img/s).
# Finished step 4995 of 5004 in epoch 0,loss=3.869, acc=0.180 (597.022 img/s).
# Finished step 4996 of 5004 in epoch 0,loss=3.666, acc=0.273 (702.124 img/s).
# Finished step 4997 of 5004 in epoch 0,loss=3.710, acc=0.250 (738.363 img/s).
# Finished step 4998 of 5004 in epoch 0,loss=3.999, acc=0.227 (711.731 img/s).
# Finished step 4999 of 5004 in epoch 0,loss=3.644, acc=0.297 (652.576 img/s).
# Finished step 5000 of 5004 in epoch 0,loss=3.843, acc=0.227 (734.773 img/s).
# Finished step 5001 of 5004 in epoch 0,loss=3.756, acc=0.242 (645.422 img/s).
# Finished step 5002 of 5004 in epoch 0,loss=3.652, acc=0.266 (716.940 img/s).
# Finished step 5003 of 5004 in epoch 0,loss=3.520, acc=0.281 (717.741 img/s).
# Finished step 5004 of 5004 in epoch 0,loss=3.850, acc=0.203 (642.940 img/s).
# Validation accuracy after epoch 0: 0.0806.
